# %%
import pandas as pd

# %%
df = pd.read_csv("/content/diabetes_prediction_dataset.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df['age'].unique()
# Out:
# array([80.  , 54.  , 28.  , 36.  , 76.  , 20.  , 44.  , 79.  , 42.  ,
#        32.  , 53.  , 78.  , 67.  , 15.  , 37.  , 40.  ,  5.  , 69.  ,
#        72.  ,  4.  , 30.  , 45.  , 43.  , 50.  , 41.  , 26.  , 34.  ,
#        73.  , 77.  , 66.  , 29.  , 60.  , 38.  ,  3.  , 57.  , 74.  ,
#        19.  , 46.  , 21.  , 59.  , 27.  , 13.  , 56.  ,  2.  ,  7.  ,
#        11.  ,  6.  , 55.  ,  9.  , 62.  , 47.  , 12.  , 68.  , 75.  ,
#        22.  , 58.  , 18.  , 24.  , 17.  , 25.  ,  0.08, 33.  , 16.  ,
#        61.  , 31.  ,  8.  , 49.  , 39.  , 65.  , 14.  , 70.  ,  0.56,
#        48.  , 51.  , 71.  ,  0.88, 64.  , 63.  , 52.  ,  0.16, 10.  ,
#        35.  , 23.  ,  0.64,  1.16,  1.64,  0.72,  1.88,  1.32,  0.8 ,
#         1.24,  1.  ,  1.8 ,  0.48,  1.56,  1.08,  0.24,  1.4 ,  0.4 ,
#         0.32,  1.72,  1.48])

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df['hypertension'].unique()
# Out:
# array([0, 1])

# %%
df['heart_disease'].unique()
# Out:
# array([1, 0])

# %%
df['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
df['bmi'].unique()
# Out:
# array([25.19, 27.32, 23.45, ..., 59.42, 44.39, 60.52])

# %%
df['HbA1c_level'].unique()
# Out:
# array([6.6, 5.7, 5. , 4.8, 6.5, 6.1, 6. , 5.8, 3.5, 6.2, 4. , 4.5, 9. ,
#        7. , 8.8, 8.2, 7.5, 6.8])

# %%
df['HbA1c_level'].unique()
# Out:
# array([6.6, 5.7, 5. , 4.8, 6.5, 6.1, 6. , 5.8, 3.5, 6.2, 4. , 4.5, 9. ,
#        7. , 8.8, 8.2, 7.5, 6.8])

# %%
df['diabetes'].unique()
# Out:
# array([0, 1])

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode= LabelEncoder()

for i in df.columns:
  if df[i].dtype == 'object':
    df[i] = encode.fit_transform(df[i])

# %%
df
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.corr()
# Out:
#                        gender       age  hypertension  heart_disease  \
# gender               1.000000 -0.030656      0.014203       0.077696
# age                 -0.030656  1.000000      0.251171       0.233354
# hypertension         0.014203  0.251171      1.000000       0.121262
# heart_disease        0.077696  0.233354      0.121262       1.000000
# smoking_history     -0.077919  0.228608      0.093177       0.027598
# bmi                 -0.022994  0.337396      0.147666       0.061198
# HbA1c_level          0.019957  0.101354      0.080939       0.067589
# blood_glucose_level  0.017199  0.110672      0.084429       0.070066
# diabetes             0.037411  0.258008      0.197823       0.171727
#
#                      smoking_history       bmi  HbA1c_level  \
# gender                     -0.077919 -0.022994     0.019957
# age                         0.228608  0.337396     0.101354
# hypertension                0.093177  0.147666     0.080939
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
cantinuous_columns = ["age","hypertension","heart_disease","bmi","HbA1c_level","blood_glucose_level","diabetes"]
categorical_columns = ["gender","smoking_history"]

# %%
from scipy import stats

# %%
def two_sample_t_test(d1,d2):
  t = 0
  f = 0
  for i in range(31):
    sample1 = d1.sample(frac=0.04)
    sample2 = d2.sample(frac =0.04)
    t_test,p_value = stats.ttest_ind(sample1,sample2)
    if p_value < 0.05:
      f += 1
    else:
      t += 1
    if f > t:
      return True
    else:
      return False

# %%
two_sample_t_test(df['age'],df['diabetes'])
# Out:
# True

# %%
two_sample_t_test(df['age'],df['hypertension'])
# Out:
# True

# %%
two_sample_t_test(df['age'],df['heart_disease'])
# Out:
# True

# %%
two_sample_t_test(df['age'],df['bmi'])
# Out:
# True

# %%
two_sample_t_test(df['age'],df['HbA1c_level'])
# Out:
# True

# %%
two_sample_t_test(df['age'],df['blood_glucose_level'])
# Out:
# True

# %%
def chi_square_test_cat_vs_cat(d1,d2):
  return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.05 else False

# %%
chi_square_test_cat_vs_cat(df['gender'],df['smoking_history'])
# Out:
# True

# %%
def annova_test(d1,d2):
  group = []
  for i in d1.unique():
    group.append(d2[d1 == i])
  return True if stats.f_oneway(*group)[1] < 0.05 else False

# %%
annova_test(df['gender'],df['age'])
# Out:
# True

# %%
annova_test(df['gender'],df['hypertension'])
# Out:
# True

# %%
final = {}
for i in df.columns:
  final[i] = {}
  for j in df.columns:
    if (i in cantinuous_columns) and (j in cantinuous_columns):
      final[i][j] = two_sample_t_test(df[i],df[j])
    elif (i in categorical_columns) and (j in cantinuous_columns):
      final[i][j] = annova_test(df[i],df[j])
    elif (i in cantinuous_columns) and (j in categorical_columns):
      final[i][j] = annova_test(df[i],df[j])
    elif (i in categorical_columns) and (j in categorical_columns):
      final[i][j] = chi_square_test_cat_vs_cat(df[i],df[j])
    if final:
      final[i][j]=1
    else:
      final[i][j]=0

# %%
import pprint

# %%
pprint.pprint(final)
# Out:
# {'HbA1c_level': {'HbA1c_level': 1,
#                  'age': 1,
#                  'blood_glucose_level': 1,
#                  'bmi': 1,
#                  'diabetes': 1,
#                  'gender': 1,
#                  'heart_disease': 1,
#                  'hypertension': 1,
#                  'smoking_history': 1},
#  'age': {'HbA1c_level': 1,
#          'age': 1,
#          'blood_glucose_level': 1,
#          'bmi': 1,
#          'diabetes': 1,
#          'gender': 1,
#          'heart_disease': 1,
#          'hypertension': 1,
#          'smoking_history': 1},
#  'blood_glucose_level': {'HbA1c_level': 1,
#                          'age': 1,
#                          'blood_glucose_level': 1,
#                          'bmi': 1,
#                          'diabetes': 1,
#                          'gender': 1,
#                          'heart_disease': 1,
#                          'hypertension': 1,
#                          'smoking_history': 1},
# ...

# %%
final_result = pd.DataFrame(final)
final_result
# Out:
#                      gender  age  hypertension  heart_disease  \
# gender                    1    1             1              1
# age                       1    1             1              1
# hypertension              1    1             1              1
# heart_disease             1    1             1              1
# smoking_history           1    1             1              1
# bmi                       1    1             1              1
# HbA1c_level               1    1             1              1
# blood_glucose_level       1    1             1              1
# diabetes                  1    1             1              1
#
#                      smoking_history  bmi  HbA1c_level  blood_glucose_level  \
# gender                             1    1            1                    1
# age                                1    1            1                    1
# hypertension                       1    1            1                    1
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(final_result,annot=True,cmap="Blues")
# Out:
# <Axes: >
